# %% [markdown]
# ## Задача 1
# ### Постройте график
# ### Назовите график
# ### Сделайте именование оси x и оси y
# ### Сделайте выводы

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.float_format = '{:20,.2f}'.format
df = pd.read_csv('kc_house_data.csv')
df
# Out:
#                id             date                price  bedrooms  \
# 0      7129300520  20141013T000000           221,900.00         3
# 1      6414100192  20141209T000000           538,000.00         3
# 2      5631500400  20150225T000000           180,000.00         2
# 3      2487200875  20141209T000000           604,000.00         4
# 4      1954400510  20150218T000000           510,000.00         3
# ...           ...              ...                  ...       ...
# 21608   263000018  20140521T000000           360,000.00         3
# 21609  6600060120  20150223T000000           400,000.00         4
# 21610  1523300141  20140623T000000           402,101.00         2
# 21611   291310100  20150116T000000           400,000.00         3
# 21612  1523300157  20141015T000000           325,000.00         2
#
#                  bathrooms  sqft_living  sqft_lot               floors  \
# 0                     1.00         1180      5650                 1.00
# ...

# %% [markdown]
# ### 1.2. Изучите стоимости недвижимости

# %%
df['price'].min(), df['price'].max()
# Out:
# (75000.0, 7700000.0)

# %%
plt.figure(figsize = (10,4))

plt.hist(df['price'], bins = 20)
plt.title('Стоимость недвижимости')
plt.xlabel('Стоимость')
plt.ylabel('Количество')
plt.xticks(range(75000, 8000000, 200000), rotation=45)
plt.grid();

# %% [markdown]
# ### Выводы:
# - Максимальное количествоо недвижимости продается в диапазоне цен от 75 000 до 450 000.
# - Основные продажи ограничиваются ценой примерно 850 000.
# - Дома с ценой выше 2 000 000 продаются крайне редко.

# %% [markdown]
# ### 1.3. Изучите распределение квадратуры жилой

# %%
plt.figure(figsize = (6,4))

plt.hist(df['sqft_living'], bins = 15)
plt.title('Распреление жилой квадратуры')
plt.xlabel('Жилые квадратные метры')
plt.ylabel('Количество')
plt.xticks(range(100, 14000, 500), rotation=45)
plt.grid();

# %% [markdown]
# ### Выводы:
# - Максимальное количествоо недвижимости продается с жилой площадью от 1 000 до 2 000 квадратных метров.
# - Основные продажи ограничиваются домами с жилой площадью примерно 3 600 квадратных метров.
# - Дома с жилой площадью выше 6 000 продаются крайне редко.

# %% [markdown]
# ### 1.4. Изучите распределение года постройки

# %%
data_yr = df['yr_built'].value_counts(ascending=True)
data_yr.head()
# Out:
# yr_built
# 1934    21
# 1935    24
# 1902    27
# 1901    29
# 1933    30
# Name: count, dtype: int64

# %%
years_list = [1900+i*10 for i in range (0,13)]

# %%
names = data_yr.index
values = data_yr.values
yr_list = list(range(1900,2025,5))
plt.figure(figsize=(16, 6))
plt.bar(names,values, width=0.7, facecolor='g', alpha=0.75)
plt.title('Годы постройки домов')
plt.xlabel('Годы')
plt.ylabel('Количество домов')
plt.grid(True)
plt.xticks(yr_list,rotation=40);
plt.show()
   
plt.figure(figsize=(16,6))
sns.set_style("darkgrid")
sns.lineplot(data=data_yr, x=names,y=values)
plt.xlabel('Годы')
plt.ylabel('Количество домов')
plt.xticks(ticks=years_list);

# %% [markdown]
# ### Выводы:
# - Кризисы строительтва были в середине 1930-х и начале 1970-х
# - Пики строительства были в конце 1960-х, в конце 1970-х, и середине нулевых

# %% [markdown]
# ## Задача №2
# ### 2.1. Изучите распределение домов от наличия вида на набережную

# %%
data_view = df['waterfront'].value_counts()
val = data_view.values
plt.pie(val,labels=['С видом', 'Без вида'],explode=[0,0.3],
        radius = 1.5, startangle=60,
        labeldistance=1.2, autopct='%.1f%%');

# %% [markdown]
# ### Выводы:
# Только 0,8% всей недвижимости продается с видом на набережную

# %% [markdown]
# ### 2.2. Изучите распределение этажей домов

# %%
df.floors.max(), df.floors.min()
# Out:
# (3.5, 1.0)

# %%
data2 = df['floors'].value_counts(normalize=True)*100
data2
# Out:
# floors
# 1.00                  49.41
# 2.00                  38.13
# 1.50                   8.84
# 3.00                   2.84
# 2.50                   0.74
# 3.50                   0.04
# Name: proportion, dtype: float64

# %%
data_floor = df['floors'].value_counts()
f_val = data_floor.values
f_ind = data_floor.index
plt.figure(figsize=(12, 6))
plt.bar(f_ind,f_val, width=0.4, facecolor='c', alpha=0.75)
plt.title('Этажность')
plt.xlabel('Этажи')
plt.ylabel('Количество домов')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,8))
explode = [0.0, 0.0, 0.0, 0.0, 0.3, 0.4]
plt.pie(data2.values, autopct='%1.2f%%', labels=data2.index, explode=explode)
plt.legend(data2.index)
plt.title('Распределение этажей домов');

# %% [markdown]
# ### Выводы:
# - Большая часть домов имеет один или два этажа;
# - Одноэтажные дома лидируют, их доля составляет 49,41%.
# - Минимальная доля продаж приходится на 2,5-этажные и 3,5-этажные дома (0,74%, 0,04%)

# %% [markdown]
# ### 2.3. Изучите распределение состояния домов

# %%
data_cond = df['condition'].value_counts(sort=False)
data_cond
cond_val= data_cond.values
cond_ind = data_cond.index
cond_explode = [0,0,0,0.6,0.3]
colors = ["#ff7f0e", "#9467bd", "#d62728","#1f77b4", "#8c564b"]
plt.title("Состояние домов")
plt.pie(cond_val, labels=cond_ind, radius = 1.5,
        startangle=-20, colors=colors,
        rotatelabels=True, explode = cond_explode,
        labeldistance=1.1, autopct='%.1f%%')
plt.legend(data_cond.index)
plt.title("Состояние домов", bbox={'facecolor':'0.8', 'pad':5})
plt.show;

# %% [markdown]
# ### Выводы:
# - Домов в плохом состоянии (1 и 2) - менее 1%
# - Домов в среднем состоянии (3) - 64.9%
# - Домов в хорошем состоянии (4) - 26.3%
# - Домов в отличном состоянии (5) - 7.9%

# %% [markdown]
# ## Задача №3
# ### Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# #### Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
sns.jointplot(data=df, x="sqft_living15", y="price", kind="reg", height=12, ratio=4);

# %%
sns.jointplot(x = df['price'], y = df['grade'], kind = 'reg', height=12, ratio=4);

# %%
g = sns.JointGrid(data=df, x="sqft_living", y="price",height=10)
g.plot_joint(sns.scatterplot, s=100, alpha=.5)
g.plot_marginals(sns.histplot, kde=True);

# %%
data = df.groupby('yr_built')['price'].mean().reset_index()
data
# Out:
#      yr_built                price
# 0        1900           581,387.21
# 1        1901           556,935.93
# 2        1902           673,007.41
# 3        1903           480,958.20
# 4        1904           583,756.64
# ..        ...                  ...
# 111      2011           544,522.00
# 112      2012           527,447.34
# 113      2013           678,545.45
# 114      2014           683,681.75
# 115      2015           759,785.16
#
# [116 rows x 2 columns]

# %%
plt.figure(figsize=(15, 6))
plt.scatter(data['yr_built'], data['price'])
plt.title('Распределение средних цен в зависимости от года постройки');

# %% [markdown]
# ### Выводы:
#
# - В диапазоне годов постройки с 1900-х до 1960-х, стоимость жилья постепенно снижается;
# - Цены на дома, построенные в 1940-х годах, имеют максимально низкие значения;
# - В диапазоне годов постройки с 1960-х до 2020-х, стоимость жилья постепенно растет;
# - Цены на дома, построенные в 2020-х годах, схожи с ценами на дома построенные в 1900-х годах;
# - Можно предположить, что старые дома имеют особую историческую значимость, что и влияет на стоимость

# %%
plt.figure(figsize=(14, 10))

sns.boxplot(x=df['grade'], y=df['price'], whis=1.0)

plt.xlabel('Класс')
plt.ylabel('Цена')
plt.title('Распределение цен в зависимости от класса дома');

# %% [markdown]
# ### Выводы:
# - С увеличением уровня класса (grade) растет разбег по цене;
# - Для домов с 7-11 классом наблюдается максимальное количество выбросов.

# %%
plt.figure(figsize=(14, 10))
sns.boxplot(x=df['price'], y=df['waterfront'].astype('str'), whis=1.5, hue=df['grade'])

plt.title('Распределение цен по береговой линии')
plt.xlabel('Цена')
plt.ylabel('Наличие набережной');

# %% [markdown]
# ### Выводы:
# - Уровень цен 50% домов, не имеющих набережную, значительно ниже, чем цена 50% домов, имеющих ее;
# - Разбег цены для домов с набережной больше, чем для домов без нее.

# %%
plt.figure(figsize = (14,10))
sns.boxplot(x = df['price'], y = df['floors'].astype('str'), whis = 1.5)
plt.xlabel('Цена')
plt.ylabel('Этажность')
plt.title('Стоимость/Этажность дома');

# %% [markdown]
# ### Выводы:
#
# - Наибольший разбег по ценам наблюдается для домов в 2,5 этажа;
# - Минимальный разбег по ценам наблюдается для домов в 3,5 этажа;
# - По 2-этажным домам наблюдается максимальное количество выбросов;
# - Дома с 3,5 этажами почти не имеют выбросов;
# - Самый дорогой дом имеет 2,5 этажа и продается почти за 8 000 000

# %%
plt.figure(figsize = (14,10))
sns.boxplot(x = df['price'], y = df['condition'].astype('str'), whis = 1.5)
plt.xlabel('Цена')
plt.ylabel('Состояние дома')
plt.title('Стоимость/Оценка состояния');

# %% [markdown]
# ### Выводы:
# - Для домов с состоянием в 1-2 почти нет выбросов;
# - Для домов с состоянием в 3-4 наблюдаются максимальное количество выбросов;
# - Самый дорогой дом имеет хорошее состояние (4) и продается почти за 8 000 000
